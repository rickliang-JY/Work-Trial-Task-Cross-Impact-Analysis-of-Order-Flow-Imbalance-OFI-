# %%
import pandas as pd 
import numpy as np 
import os

# %%
data = pd.read_csv('../data/AAPL20250102_original.csv', index_col = 1)
data = data.drop(columns = ['ts_recv','rtype', 'publisher_id', 'instrument_id', 'flags', 'ts_in_delta', 'sequence'])
data = data.drop(columns=[col for col in data.columns if any(char.isdigit() for char in col) and (int(''.join(filter(str.isdigit, col))) > 5 or int(''.join(filter(str.isdigit, col))) == 0)])
data.dropna(inplace=True)

data.head(10)
# Out:
#                                     action side  depth   price  size  \
# ts_event
# 2025-01-02 09:00:01.193543605+00:00      A    A      2  254.00    20
# 2025-01-02 09:00:01.223799811+00:00      A    A      4  267.73     5
# 2025-01-02 09:00:01.225733734+00:00      A    B      3  238.44     5
# 2025-01-02 09:00:01.391336672+00:00      A    B      1  251.16    29
# 2025-01-02 09:00:01.458667661+00:00      A    A      1  251.53    27
# 2025-01-02 09:00:01.674388803+00:00      C    B      0  251.17   200
# 2025-01-02 09:00:01.674401932+00:00      A    B      1  251.14   200
# 2025-01-02 09:00:01.993068686+00:00      A    B      2  251.11    28
# 2025-01-02 09:00:02.288070034+00:00      C    B      0  251.16    29
# 2025-01-02 09:00:03.438169085+00:00      C    A      0  251.48   200
#
#                                      bid_px_01  ask_px_01  bid_sz_01  \
# ts_event
# 2025-01-02 09:00:01.193543605+00:00     248.18     251.90        399
# ...

# %%
data.to_csv('../data/AAPL20250102_after.csv')
